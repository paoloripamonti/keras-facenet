# %% [markdown]
# # Tensorflow FaceNet to Keras model

# %%
import os
import re
import numpy as np
import tensorflow as tf

import sys
sys.path.append('../code/')
from inception_resnet_v1 import *
# Out:
# Using TensorFlow backend.

# %%
tf_model_dir = './model/tf/20180402-114759/'
npy_weights_dir = './model/keras/npy_weights/'
weights_dir = './model/keras/weights/'
model_dir = './model/keras/model/'

weights_filename = 'facenet_keras_weights.h5'
model_filename = 'facenet_keras.h5'

# %%
os.makedirs(npy_weights_dir, exist_ok=True)
os.makedirs(weights_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)

# %%
# regex for renaming the tensors to their corresponding Keras counterpart
re_repeat = re.compile(r'Repeat_[0-9_]*b')
re_block8 = re.compile(r'Block8_[A-Za-z]')

def get_filename(key):
    filename = str(key)
    filename = filename.replace('/', '_')
    filename = filename.replace('InceptionResnetV1_', '')

    # remove "Repeat" scope from filename
    filename = re_repeat.sub('B', filename)

    if re_block8.match(filename):
        # the last block8 has different name with the previous 5 occurrences
        filename = filename.replace('Block8', 'Block8_6')

    # from TF to Keras naming
    filename = filename.replace('_weights', '_kernel')
    filename = filename.replace('_biases', '_bias')

    return filename + '.npy'


def extract_tensors_from_checkpoint_file(filename, output_folder):
    reader = tf.train.NewCheckpointReader(filename)

    for key in reader.get_variable_to_shape_map():
        # not saving the following tensors
        if key == 'global_step':
            continue
        if 'AuxLogit' in key:
            continue

        # convert tensor name into the corresponding Keras layer weight name and save
        path = os.path.join(output_folder, get_filename(key))
        arr = reader.get_tensor(key)
        np.save(path, arr)

# %%
extract_tensors_from_checkpoint_file(tf_model_dir+'model-20180402-114759.ckpt-275', npy_weights_dir)

# %%
model = InceptionResNetV1(classes=512)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 160, 160, 3)  0
# __________________________________________________________________________________________________
# Conv2d_1a_3x3 (Conv2D)          (None, 79, 79, 32)   864         input_3[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_BatchNorm (BatchN (None, 79, 79, 32)   96          Conv2d_1a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_1a_3x3_Activation (Activ (None, 79, 79, 32)   0           Conv2d_1a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_2a_3x3 (Conv2D)          (None, 77, 77, 32)   9216        Conv2d_1a_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_2a_3x3_BatchNorm (BatchN (None, 77, 77, 32)   96          Conv2d_2a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_2a_3x3_Activation (Activ (None, 77, 77, 32)   0           Conv2d_2a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_2b_3x3 (Conv2D)          (None, 77, 77, 64)   18432       Conv2d_2a_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_2b_3x3_BatchNorm (BatchN (None, 77, 77, 64)   192         Conv2d_2b_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_2b_3x3_Activation (Activ (None, 77, 77, 64)   0           Conv2d_2b_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# MaxPool_3a_3x3 (MaxPooling2D)   (None, 38, 38, 64)   0           Conv2d_2b_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_3b_1x1 (Conv2D)          (None, 38, 38, 80)   5120        MaxPool_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_3b_1x1_BatchNorm (BatchN (None, 38, 38, 80)   240         Conv2d_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv2d_3b_1x1_Activation (Activ (None, 38, 38, 80)   0           Conv2d_3b_1x1_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_4a_3x3 (Conv2D)          (None, 36, 36, 192)  138240      Conv2d_3b_1x1_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_4a_3x3_BatchNorm (BatchN (None, 36, 36, 192)  576         Conv2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_4a_3x3_Activation (Activ (None, 36, 36, 192)  0           Conv2d_4a_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Conv2d_4b_3x3 (Conv2D)          (None, 17, 17, 256)  442368      Conv2d_4a_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Conv2d_4b_3x3_BatchNorm (BatchN (None, 17, 17, 256)  768         Conv2d_4b_3x3[0][0]
# __________________________________________________________________________________________________
# Conv2d_4b_3x3_Activation (Activ (None, 17, 17, 256)  0           Conv2d_4b_3x3_BatchNorm[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   8192        Conv2d_4b_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_1_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_1_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   8192        Conv2d_4b_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_1_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_1_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_1_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_1_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_1_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_1_Branch_0_Conv2d_1x1 ( (None, 17, 17, 32)   8192        Conv2d_4b_3x3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_1_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   9216        Block35_1_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_1_Branch_0_Conv2d_1x1_B (None, 17, 17, 32)   96          Block35_1_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_1_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   96          Block35_1_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_1_Branch_0_Conv2d_1x1_A (None, 17, 17, 32)   0           Block35_1_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_1_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_1_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_1_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   0           Block35_1_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_1_Concatenate (Concaten (None, 17, 17, 96)   0           Block35_1_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_1_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_1_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_1_Conv2d_1x1 (Conv2D)   (None, 17, 17, 256)  24832       Block35_1_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 17, 17, 256)  0           Block35_1_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 17, 17, 256)  0           Conv2d_4b_3x3_Activation[0][0]
#                                                                  lambda_43[0][0]
# __________________________________________________________________________________________________
# Block35_1_Activation (Activatio (None, 17, 17, 256)  0           add_43[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_2_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_2_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_2_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_2_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_2_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_2_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_2_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_2_Branch_0_Conv2d_1x1 ( (None, 17, 17, 32)   8192        Block35_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_2_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   9216        Block35_2_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_2_Branch_0_Conv2d_1x1_B (None, 17, 17, 32)   96          Block35_2_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_2_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   96          Block35_2_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_2_Branch_0_Conv2d_1x1_A (None, 17, 17, 32)   0           Block35_2_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_2_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_2_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_2_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   0           Block35_2_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_2_Concatenate (Concaten (None, 17, 17, 96)   0           Block35_2_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_2_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_2_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_2_Conv2d_1x1 (Conv2D)   (None, 17, 17, 256)  24832       Block35_2_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 17, 17, 256)  0           Block35_2_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 17, 17, 256)  0           Block35_1_Activation[0][0]
#                                                                  lambda_44[0][0]
# __________________________________________________________________________________________________
# Block35_2_Activation (Activatio (None, 17, 17, 256)  0           add_44[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_3_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_3_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_3_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_3_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_3_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_3_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_3_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_3_Branch_0_Conv2d_1x1 ( (None, 17, 17, 32)   8192        Block35_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_3_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   9216        Block35_3_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_3_Branch_0_Conv2d_1x1_B (None, 17, 17, 32)   96          Block35_3_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_3_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   96          Block35_3_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_3_Branch_0_Conv2d_1x1_A (None, 17, 17, 32)   0           Block35_3_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_3_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_3_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_3_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   0           Block35_3_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_3_Concatenate (Concaten (None, 17, 17, 96)   0           Block35_3_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_3_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_3_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_3_Conv2d_1x1 (Conv2D)   (None, 17, 17, 256)  24832       Block35_3_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 17, 17, 256)  0           Block35_3_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 17, 17, 256)  0           Block35_2_Activation[0][0]
#                                                                  lambda_45[0][0]
# __________________________________________________________________________________________________
# Block35_3_Activation (Activatio (None, 17, 17, 256)  0           add_45[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_4_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_4_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_4_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_4_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_4_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_4_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_4_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_4_Branch_0_Conv2d_1x1 ( (None, 17, 17, 32)   8192        Block35_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_4_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   9216        Block35_4_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_4_Branch_0_Conv2d_1x1_B (None, 17, 17, 32)   96          Block35_4_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_4_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   96          Block35_4_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_4_Branch_0_Conv2d_1x1_A (None, 17, 17, 32)   0           Block35_4_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_4_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_4_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_4_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   0           Block35_4_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_4_Concatenate (Concaten (None, 17, 17, 96)   0           Block35_4_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_4_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_4_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_4_Conv2d_1x1 (Conv2D)   (None, 17, 17, 256)  24832       Block35_4_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 17, 17, 256)  0           Block35_4_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 17, 17, 256)  0           Block35_3_Activation[0][0]
#                                                                  lambda_46[0][0]
# __________________________________________________________________________________________________
# Block35_4_Activation (Activatio (None, 17, 17, 256)  0           add_46[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_5_Branch_2_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_5_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   8192        Block35_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_5_Branch_2_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   96          Block35_5_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_5_Branch_2_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0a_1x (None, 17, 17, 32)   0           Block35_5_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_5_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_5_Branch_0_Conv2d_1x1 ( (None, 17, 17, 32)   8192        Block35_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   9216        Block35_5_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   9216        Block35_5_Branch_2_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_5_Branch_0_Conv2d_1x1_B (None, 17, 17, 32)   96          Block35_5_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   96          Block35_5_Branch_1_Conv2d_0b_3x3[
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   96          Block35_5_Branch_2_Conv2d_0c_3x3[
# __________________________________________________________________________________________________
# Block35_5_Branch_0_Conv2d_1x1_A (None, 17, 17, 32)   0           Block35_5_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block35_5_Branch_1_Conv2d_0b_3x (None, 17, 17, 32)   0           Block35_5_Branch_1_Conv2d_0b_3x3_
# __________________________________________________________________________________________________
# Block35_5_Branch_2_Conv2d_0c_3x (None, 17, 17, 32)   0           Block35_5_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_5_Concatenate (Concaten (None, 17, 17, 96)   0           Block35_5_Branch_0_Conv2d_1x1_Act
#                                                                  Block35_5_Branch_1_Conv2d_0b_3x3_
#                                                                  Block35_5_Branch_2_Conv2d_0c_3x3_
# __________________________________________________________________________________________________
# Block35_5_Conv2d_1x1 (Conv2D)   (None, 17, 17, 256)  24832       Block35_5_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 17, 17, 256)  0           Block35_5_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 17, 17, 256)  0           Block35_4_Activation[0][0]
#                                                                  lambda_47[0][0]
# __________________________________________________________________________________________________
# Block35_5_Activation (Activatio (None, 17, 17, 256)  0           add_47[0][0]
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_0a_1x1 (None, 17, 17, 192)  49152       Block35_5_Activation[0][0]
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_0a_1x1 (None, 17, 17, 192)  576         Mixed_6a_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_0a_1x1 (None, 17, 17, 192)  0           Mixed_6a_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_0b_3x3 (None, 17, 17, 192)  331776      Mixed_6a_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_0b_3x3 (None, 17, 17, 192)  576         Mixed_6a_Branch_1_Conv2d_0b_3x3[0
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_0b_3x3 (None, 17, 17, 192)  0           Mixed_6a_Branch_1_Conv2d_0b_3x3_B
# __________________________________________________________________________________________________
# Mixed_6a_Branch_0_Conv2d_1a_3x3 (None, 8, 8, 384)    884736      Block35_5_Activation[0][0]
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_1a_3x3 (None, 8, 8, 256)    442368      Mixed_6a_Branch_1_Conv2d_0b_3x3_A
# __________________________________________________________________________________________________
# Mixed_6a_Branch_0_Conv2d_1a_3x3 (None, 8, 8, 384)    1152        Mixed_6a_Branch_0_Conv2d_1a_3x3[0
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_1a_3x3 (None, 8, 8, 256)    768         Mixed_6a_Branch_1_Conv2d_1a_3x3[0
# __________________________________________________________________________________________________
# Mixed_6a_Branch_0_Conv2d_1a_3x3 (None, 8, 8, 384)    0           Mixed_6a_Branch_0_Conv2d_1a_3x3_B
# __________________________________________________________________________________________________
# Mixed_6a_Branch_1_Conv2d_1a_3x3 (None, 8, 8, 256)    0           Mixed_6a_Branch_1_Conv2d_1a_3x3_B
# __________________________________________________________________________________________________
# Mixed_6a_Branch_2_MaxPool_1a_3x (None, 8, 8, 256)    0           Block35_5_Activation[0][0]
# __________________________________________________________________________________________________
# Mixed_6a (Concatenate)          (None, 8, 8, 896)    0           Mixed_6a_Branch_0_Conv2d_1a_3x3_A
#                                                                  Mixed_6a_Branch_1_Conv2d_1a_3x3_A
#                                                                  Mixed_6a_Branch_2_MaxPool_1a_3x3[
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    114688      Mixed_6a[0][0]
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    384         Block17_1_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    0           Block17_1_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    114688      Block17_1_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    384         Block17_1_Branch_1_Conv2d_0b_1x7[
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    0           Block17_1_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_1_Branch_0_Conv2d_1x1 ( (None, 8, 8, 128)    114688      Mixed_6a[0][0]
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    114688      Block17_1_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_1_Branch_0_Conv2d_1x1_B (None, 8, 8, 128)    384         Block17_1_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    384         Block17_1_Branch_1_Conv2d_0c_7x1[
# __________________________________________________________________________________________________
# Block17_1_Branch_0_Conv2d_1x1_A (None, 8, 8, 128)    0           Block17_1_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block17_1_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    0           Block17_1_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_1_Concatenate (Concaten (None, 8, 8, 256)    0           Block17_1_Branch_0_Conv2d_1x1_Act
#                                                                  Block17_1_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_1_Conv2d_1x1 (Conv2D)   (None, 8, 8, 896)    230272      Block17_1_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 8, 8, 896)    0           Block17_1_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 8, 8, 896)    0           Mixed_6a[0][0]
#                                                                  lambda_48[0][0]
# __________________________________________________________________________________________________
# Block17_1_Activation (Activatio (None, 8, 8, 896)    0           add_48[0][0]
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    114688      Block17_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    384         Block17_2_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    0           Block17_2_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    114688      Block17_2_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    384         Block17_2_Branch_1_Conv2d_0b_1x7[
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    0           Block17_2_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_2_Branch_0_Conv2d_1x1 ( (None, 8, 8, 128)    114688      Block17_1_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    114688      Block17_2_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_2_Branch_0_Conv2d_1x1_B (None, 8, 8, 128)    384         Block17_2_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    384         Block17_2_Branch_1_Conv2d_0c_7x1[
# __________________________________________________________________________________________________
# Block17_2_Branch_0_Conv2d_1x1_A (None, 8, 8, 128)    0           Block17_2_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block17_2_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    0           Block17_2_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_2_Concatenate (Concaten (None, 8, 8, 256)    0           Block17_2_Branch_0_Conv2d_1x1_Act
#                                                                  Block17_2_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_2_Conv2d_1x1 (Conv2D)   (None, 8, 8, 896)    230272      Block17_2_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 8, 8, 896)    0           Block17_2_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 8, 8, 896)    0           Block17_1_Activation[0][0]
#                                                                  lambda_49[0][0]
# __________________________________________________________________________________________________
# Block17_2_Activation (Activatio (None, 8, 8, 896)    0           add_49[0][0]
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    114688      Block17_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    384         Block17_3_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    0           Block17_3_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    114688      Block17_3_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    384         Block17_3_Branch_1_Conv2d_0b_1x7[
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    0           Block17_3_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_3_Branch_0_Conv2d_1x1 ( (None, 8, 8, 128)    114688      Block17_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    114688      Block17_3_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_3_Branch_0_Conv2d_1x1_B (None, 8, 8, 128)    384         Block17_3_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    384         Block17_3_Branch_1_Conv2d_0c_7x1[
# __________________________________________________________________________________________________
# Block17_3_Branch_0_Conv2d_1x1_A (None, 8, 8, 128)    0           Block17_3_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block17_3_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    0           Block17_3_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_3_Concatenate (Concaten (None, 8, 8, 256)    0           Block17_3_Branch_0_Conv2d_1x1_Act
#                                                                  Block17_3_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_3_Conv2d_1x1 (Conv2D)   (None, 8, 8, 896)    230272      Block17_3_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 8, 8, 896)    0           Block17_3_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 8, 8, 896)    0           Block17_2_Activation[0][0]
#                                                                  lambda_50[0][0]
# __________________________________________________________________________________________________
# Block17_3_Activation (Activatio (None, 8, 8, 896)    0           add_50[0][0]
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    114688      Block17_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    384         Block17_4_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    0           Block17_4_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    114688      Block17_4_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    384         Block17_4_Branch_1_Conv2d_0b_1x7[
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    0           Block17_4_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_4_Branch_0_Conv2d_1x1 ( (None, 8, 8, 128)    114688      Block17_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    114688      Block17_4_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_4_Branch_0_Conv2d_1x1_B (None, 8, 8, 128)    384         Block17_4_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    384         Block17_4_Branch_1_Conv2d_0c_7x1[
# __________________________________________________________________________________________________
# Block17_4_Branch_0_Conv2d_1x1_A (None, 8, 8, 128)    0           Block17_4_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# Block17_4_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    0           Block17_4_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_4_Concatenate (Concaten (None, 8, 8, 256)    0           Block17_4_Branch_0_Conv2d_1x1_Act
#                                                                  Block17_4_Branch_1_Conv2d_0c_7x1_
# __________________________________________________________________________________________________
# Block17_4_Conv2d_1x1 (Conv2D)   (None, 8, 8, 896)    230272      Block17_4_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 8, 8, 896)    0           Block17_4_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 8, 8, 896)    0           Block17_3_Activation[0][0]
#                                                                  lambda_51[0][0]
# __________________________________________________________________________________________________
# Block17_4_Activation (Activatio (None, 8, 8, 896)    0           add_51[0][0]
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    114688      Block17_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    384         Block17_5_Branch_1_Conv2d_0a_1x1[
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0a_1x (None, 8, 8, 128)    0           Block17_5_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    114688      Block17_5_Branch_1_Conv2d_0a_1x1_
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    384         Block17_5_Branch_1_Conv2d_0b_1x7[
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0b_1x (None, 8, 8, 128)    0           Block17_5_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_5_Branch_0_Conv2d_1x1 ( (None, 8, 8, 128)    114688      Block17_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    114688      Block17_5_Branch_1_Conv2d_0b_1x7_
# __________________________________________________________________________________________________
# Block17_5_Branch_0_Conv2d_1x1_B (None, 8, 8, 128)    384         Block17_5_Branch_0_Conv2d_1x1[0][
# __________________________________________________________________________________________________
# Block17_5_Branch_1_Conv2d_0c_7x (None, 8, 8, 128)    384         Block17_5_Branch_1_Conv2d_0c_7x1[
# __________________________________________________________________________________________________
# Block17_5_Branch_0_Conv2d_1x1_A (None, 8, 8, 128)    0           Block17_5_Branch_0_Conv2d_1x1_Bat
# __________________________________________________________________________________________________
# ...
# Block8_2_Conv2d_1x1 (Conv2D)    (None, 3, 3, 1792)   689920      Block8_2_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 3, 3, 1792)   0           Block8_2_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 3, 3, 1792)   0           Block8_1_Activation[0][0]
#                                                                  lambda_59[0][0]
# __________________________________________________________________________________________________
# Block8_2_Activation (Activation (None, 3, 3, 1792)   0           add_59[0][0]
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    344064      Block8_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_3_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_3_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    110592      Block8_3_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    576         Block8_3_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    0           Block8_3_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_3_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    344064      Block8_2_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    110592      Block8_3_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_3_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_3_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    576         Block8_3_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_3_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_3_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_3_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    0           Block8_3_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_3_Concatenate (Concatena (None, 3, 3, 384)    0           Block8_3_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_3_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_3_Conv2d_1x1 (Conv2D)    (None, 3, 3, 1792)   689920      Block8_3_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 3, 3, 1792)   0           Block8_3_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 3, 3, 1792)   0           Block8_2_Activation[0][0]
#                                                                  lambda_60[0][0]
# __________________________________________________________________________________________________
# Block8_3_Activation (Activation (None, 3, 3, 1792)   0           add_60[0][0]
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    344064      Block8_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_4_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_4_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    110592      Block8_4_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    576         Block8_4_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    0           Block8_4_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_4_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    344064      Block8_3_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    110592      Block8_4_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_4_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_4_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    576         Block8_4_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_4_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_4_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_4_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    0           Block8_4_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_4_Concatenate (Concatena (None, 3, 3, 384)    0           Block8_4_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_4_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_4_Conv2d_1x1 (Conv2D)    (None, 3, 3, 1792)   689920      Block8_4_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 3, 3, 1792)   0           Block8_4_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 3, 3, 1792)   0           Block8_3_Activation[0][0]
#                                                                  lambda_61[0][0]
# __________________________________________________________________________________________________
# Block8_4_Activation (Activation (None, 3, 3, 1792)   0           add_61[0][0]
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    344064      Block8_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_5_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_5_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    110592      Block8_5_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    576         Block8_5_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    0           Block8_5_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_5_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    344064      Block8_4_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    110592      Block8_5_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_5_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_5_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    576         Block8_5_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_5_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_5_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_5_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    0           Block8_5_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_5_Concatenate (Concatena (None, 3, 3, 384)    0           Block8_5_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_5_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_5_Conv2d_1x1 (Conv2D)    (None, 3, 3, 1792)   689920      Block8_5_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 3, 3, 1792)   0           Block8_5_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 3, 3, 1792)   0           Block8_4_Activation[0][0]
#                                                                  lambda_62[0][0]
# __________________________________________________________________________________________________
# Block8_5_Activation (Activation (None, 3, 3, 1792)   0           add_62[0][0]
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    344064      Block8_5_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    576         Block8_6_Branch_1_Conv2d_0a_1x1[0
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0a_1x1 (None, 3, 3, 192)    0           Block8_6_Branch_1_Conv2d_0a_1x1_B
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    110592      Block8_6_Branch_1_Conv2d_0a_1x1_A
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    576         Block8_6_Branch_1_Conv2d_0b_1x3[0
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0b_1x3 (None, 3, 3, 192)    0           Block8_6_Branch_1_Conv2d_0b_1x3_B
# __________________________________________________________________________________________________
# Block8_6_Branch_0_Conv2d_1x1 (C (None, 3, 3, 192)    344064      Block8_5_Activation[0][0]
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    110592      Block8_6_Branch_1_Conv2d_0b_1x3_A
# __________________________________________________________________________________________________
# Block8_6_Branch_0_Conv2d_1x1_Ba (None, 3, 3, 192)    576         Block8_6_Branch_0_Conv2d_1x1[0][0
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    576         Block8_6_Branch_1_Conv2d_0c_3x1[0
# __________________________________________________________________________________________________
# Block8_6_Branch_0_Conv2d_1x1_Ac (None, 3, 3, 192)    0           Block8_6_Branch_0_Conv2d_1x1_Batc
# __________________________________________________________________________________________________
# Block8_6_Branch_1_Conv2d_0c_3x1 (None, 3, 3, 192)    0           Block8_6_Branch_1_Conv2d_0c_3x1_B
# __________________________________________________________________________________________________
# Block8_6_Concatenate (Concatena (None, 3, 3, 384)    0           Block8_6_Branch_0_Conv2d_1x1_Acti
#                                                                  Block8_6_Branch_1_Conv2d_0c_3x1_A
# __________________________________________________________________________________________________
# Block8_6_Conv2d_1x1 (Conv2D)    (None, 3, 3, 1792)   689920      Block8_6_Concatenate[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 3, 3, 1792)   0           Block8_6_Conv2d_1x1[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 3, 3, 1792)   0           Block8_5_Activation[0][0]
#                                                                  lambda_63[0][0]
# __________________________________________________________________________________________________
# AvgPool (GlobalAveragePooling2D (None, 1792)         0           add_63[0][0]
# __________________________________________________________________________________________________
# Dropout (Dropout)               (None, 1792)         0           AvgPool[0][0]
# __________________________________________________________________________________________________
# Bottleneck (Dense)              (None, 512)          917504      Dropout[0][0]
# __________________________________________________________________________________________________
# Bottleneck_BatchNorm (BatchNorm (None, 512)          1536        Bottleneck[0][0]
# ==================================================================================================
# Total params: 23,497,424
# Trainable params: 23,467,824
# Non-trainable params: 29,600
# __________________________________________________________________________________________________

# %%
for layer in model.layers:
    if layer.weights:
        weights = []
        for w in layer.weights:
            weight_name = os.path.basename(w.name).replace(':0', '')
            weight_file = layer.name + '_' + weight_name + '.npy'
            weight_arr = np.load(os.path.join(npy_weights_dir, weight_file))
            weights.append(weight_arr)
            print(weight_file, weight_arr.shape)
        layer.set_weights(weights)

#print('Saving weights...')
#model.save_weights(os.path.join(weights_dir, weights_filename))
print('Saving model...')
model.save(os.path.join(model_dir, model_filename))
# Out:
# Conv2d_1a_3x3_kernel.npy (3, 3, 3, 32)
# Conv2d_1a_3x3_BatchNorm_beta.npy (32,)
# Conv2d_1a_3x3_BatchNorm_moving_mean.npy (32,)
# Conv2d_1a_3x3_BatchNorm_moving_variance.npy (32,)
# Conv2d_2a_3x3_kernel.npy (3, 3, 32, 32)
# Conv2d_2a_3x3_BatchNorm_beta.npy (32,)
# Conv2d_2a_3x3_BatchNorm_moving_mean.npy (32,)
# Conv2d_2a_3x3_BatchNorm_moving_variance.npy (32,)
# Conv2d_2b_3x3_kernel.npy (3, 3, 32, 64)
# Conv2d_2b_3x3_BatchNorm_beta.npy (64,)
# Conv2d_2b_3x3_BatchNorm_moving_mean.npy (64,)
# Conv2d_2b_3x3_BatchNorm_moving_variance.npy (64,)
# Conv2d_3b_1x1_kernel.npy (1, 1, 64, 80)
# Conv2d_3b_1x1_BatchNorm_beta.npy (80,)
# Conv2d_3b_1x1_BatchNorm_moving_mean.npy (80,)
# Conv2d_3b_1x1_BatchNorm_moving_variance.npy (80,)
# Conv2d_4a_3x3_kernel.npy (3, 3, 80, 192)
# Conv2d_4a_3x3_BatchNorm_beta.npy (192,)
# Conv2d_4a_3x3_BatchNorm_moving_mean.npy (192,)
# Conv2d_4a_3x3_BatchNorm_moving_variance.npy (192,)
# Conv2d_4b_3x3_kernel.npy (3, 3, 192, 256)
# Conv2d_4b_3x3_BatchNorm_beta.npy (256,)
# Conv2d_4b_3x3_BatchNorm_moving_mean.npy (256,)
# Conv2d_4b_3x3_BatchNorm_moving_variance.npy (256,)
# Block35_1_Branch_2_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_1_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_1_Branch_2_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_1_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 256, 32)
# Block35_1_Branch_1_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_1_Branch_2_Conv2d_0c_3x3_kernel.npy (3, 3, 32, 32)
# Block35_1_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (32,)
# Block35_1_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_1_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm_beta.npy (32,)
# Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_1_Conv2d_1x1_kernel.npy (1, 1, 96, 256)
# Block35_1_Conv2d_1x1_bias.npy (256,)
# Block35_2_Branch_2_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_2_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_2_Branch_2_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_2_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 256, 32)
# Block35_2_Branch_1_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_2_Branch_2_Conv2d_0c_3x3_kernel.npy (3, 3, 32, 32)
# Block35_2_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (32,)
# Block35_2_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_2_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm_beta.npy (32,)
# Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_2_Conv2d_1x1_kernel.npy (1, 1, 96, 256)
# Block35_2_Conv2d_1x1_bias.npy (256,)
# Block35_3_Branch_2_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_3_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_3_Branch_2_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_3_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 256, 32)
# Block35_3_Branch_1_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_3_Branch_2_Conv2d_0c_3x3_kernel.npy (3, 3, 32, 32)
# Block35_3_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (32,)
# Block35_3_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_3_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm_beta.npy (32,)
# Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_3_Conv2d_1x1_kernel.npy (1, 1, 96, 256)
# Block35_3_Conv2d_1x1_bias.npy (256,)
# Block35_4_Branch_2_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_4_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_4_Branch_2_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_4_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 256, 32)
# Block35_4_Branch_1_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_4_Branch_2_Conv2d_0c_3x3_kernel.npy (3, 3, 32, 32)
# Block35_4_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (32,)
# Block35_4_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_4_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm_beta.npy (32,)
# Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_4_Conv2d_1x1_kernel.npy (1, 1, 96, 256)
# Block35_4_Conv2d_1x1_bias.npy (256,)
# Block35_5_Branch_2_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_5_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 32)
# Block35_5_Branch_2_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (32,)
# Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_5_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 256, 32)
# Block35_5_Branch_1_Conv2d_0b_3x3_kernel.npy (3, 3, 32, 32)
# Block35_5_Branch_2_Conv2d_0c_3x3_kernel.npy (3, 3, 32, 32)
# Block35_5_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (32,)
# Block35_5_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (32,)
# Block35_5_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (32,)
# Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm_beta.npy (32,)
# Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm_beta.npy (32,)
# Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_mean.npy (32,)
# Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm_moving_variance.npy (32,)
# Block35_5_Conv2d_1x1_kernel.npy (1, 1, 96, 256)
# Block35_5_Conv2d_1x1_bias.npy (256,)
# Mixed_6a_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 256, 192)
# Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Mixed_6a_Branch_1_Conv2d_0b_3x3_kernel.npy (3, 3, 192, 192)
# Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm_beta.npy (192,)
# Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (192,)
# Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (192,)
# Mixed_6a_Branch_0_Conv2d_1a_3x3_kernel.npy (3, 3, 256, 384)
# Mixed_6a_Branch_1_Conv2d_1a_3x3_kernel.npy (3, 3, 192, 256)
# Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm_beta.npy (384,)
# Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm_moving_mean.npy (384,)
# Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm_moving_variance.npy (384,)
# Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm_beta.npy (256,)
# Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm_moving_mean.npy (256,)
# Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm_moving_variance.npy (256,)
# Block17_1_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_1_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_1_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_1_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_1_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_1_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_1_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_1_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_1_Conv2d_1x1_bias.npy (896,)
# Block17_2_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_2_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_2_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_2_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_2_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_2_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_2_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_2_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_2_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_2_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_2_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_2_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_2_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_2_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_2_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_2_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_2_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_2_Conv2d_1x1_bias.npy (896,)
# Block17_3_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_3_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_3_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_3_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_3_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_3_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_3_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_3_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_3_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_3_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_3_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_3_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_3_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_3_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_3_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_3_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_3_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_3_Conv2d_1x1_bias.npy (896,)
# Block17_4_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_4_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_4_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_4_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_4_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_4_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_4_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_4_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_4_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_4_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_4_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_4_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_4_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_4_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_4_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_4_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_4_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_4_Conv2d_1x1_bias.npy (896,)
# Block17_5_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_5_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_5_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_5_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_5_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_5_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_5_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_5_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_5_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_5_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_5_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_5_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_5_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_5_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_5_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_5_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_5_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_5_Conv2d_1x1_bias.npy (896,)
# Block17_6_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_6_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_6_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_6_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_6_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_6_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_6_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_6_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_6_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_6_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_6_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_6_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_6_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_6_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_6_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_6_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_6_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_6_Conv2d_1x1_bias.npy (896,)
# Block17_7_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_7_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_7_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_7_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_7_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_7_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_7_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_7_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_7_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_7_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_7_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_7_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_7_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_7_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_7_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_7_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_7_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_7_Conv2d_1x1_bias.npy (896,)
# Block17_8_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_8_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_8_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_8_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_8_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_8_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_8_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_8_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_8_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_8_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_8_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_8_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_8_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_8_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_8_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_8_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_8_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_8_Conv2d_1x1_bias.npy (896,)
# Block17_9_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_9_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_9_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_9_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_9_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_9_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_9_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_9_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_9_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_9_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_9_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_9_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_9_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_9_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_9_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_9_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_9_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_9_Conv2d_1x1_bias.npy (896,)
# Block17_10_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 128)
# Block17_10_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (128,)
# Block17_10_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_10_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_10_Branch_1_Conv2d_0b_1x7_kernel.npy (1, 7, 128, 128)
# Block17_10_Branch_1_Conv2d_0b_1x7_BatchNorm_beta.npy (128,)
# Block17_10_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_mean.npy (128,)
# Block17_10_Branch_1_Conv2d_0b_1x7_BatchNorm_moving_variance.npy (128,)
# Block17_10_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 896, 128)
# Block17_10_Branch_1_Conv2d_0c_7x1_kernel.npy (7, 1, 128, 128)
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (128,)
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (128,)
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (128,)
# Block17_10_Branch_1_Conv2d_0c_7x1_BatchNorm_beta.npy (128,)
# Block17_10_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_mean.npy (128,)
# Block17_10_Branch_1_Conv2d_0c_7x1_BatchNorm_moving_variance.npy (128,)
# Block17_10_Conv2d_1x1_kernel.npy (1, 1, 256, 896)
# Block17_10_Conv2d_1x1_bias.npy (896,)
# Mixed_7a_Branch_2_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 256)
# Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm_beta.npy (256,)
# Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (256,)
# Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (256,)
# Mixed_7a_Branch_0_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 256)
# Mixed_7a_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 896, 256)
# Mixed_7a_Branch_2_Conv2d_0b_3x3_kernel.npy (3, 3, 256, 256)
# Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm_beta.npy (256,)
# Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (256,)
# Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (256,)
# Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (256,)
# Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (256,)
# Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (256,)
# Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm_beta.npy (256,)
# Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_mean.npy (256,)
# Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm_moving_variance.npy (256,)
# Mixed_7a_Branch_0_Conv2d_1a_3x3_kernel.npy (3, 3, 256, 384)
# Mixed_7a_Branch_1_Conv2d_1a_3x3_kernel.npy (3, 3, 256, 256)
# Mixed_7a_Branch_2_Conv2d_1a_3x3_kernel.npy (3, 3, 256, 256)
# Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm_beta.npy (384,)
# Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm_moving_mean.npy (384,)
# Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm_moving_variance.npy (384,)
# Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm_beta.npy (256,)
# Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm_moving_mean.npy (256,)
# Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm_moving_variance.npy (256,)
# Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm_beta.npy (256,)
# Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm_moving_mean.npy (256,)
# Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm_moving_variance.npy (256,)
# Block8_1_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_1_Branch_1_Conv2d_0b_1x3_kernel.npy (1, 3, 192, 192)
# Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm_beta.npy (192,)
# Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_mean.npy (192,)
# Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_variance.npy (192,)
# Block8_1_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_1_Branch_1_Conv2d_0c_3x1_kernel.npy (3, 1, 192, 192)
# Block8_1_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (192,)
# Block8_1_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_1_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm_beta.npy (192,)
# Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_mean.npy (192,)
# Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_variance.npy (192,)
# Block8_1_Conv2d_1x1_kernel.npy (1, 1, 384, 1792)
# Block8_1_Conv2d_1x1_bias.npy (1792,)
# Block8_2_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_2_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Block8_2_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_2_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_2_Branch_1_Conv2d_0b_1x3_kernel.npy (1, 3, 192, 192)
# Block8_2_Branch_1_Conv2d_0b_1x3_BatchNorm_beta.npy (192,)
# Block8_2_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_mean.npy (192,)
# Block8_2_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_variance.npy (192,)
# Block8_2_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_2_Branch_1_Conv2d_0c_3x1_kernel.npy (3, 1, 192, 192)
# Block8_2_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (192,)
# Block8_2_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_2_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_2_Branch_1_Conv2d_0c_3x1_BatchNorm_beta.npy (192,)
# Block8_2_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_mean.npy (192,)
# Block8_2_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_variance.npy (192,)
# Block8_2_Conv2d_1x1_kernel.npy (1, 1, 384, 1792)
# Block8_2_Conv2d_1x1_bias.npy (1792,)
# Block8_3_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_3_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Block8_3_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_3_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_3_Branch_1_Conv2d_0b_1x3_kernel.npy (1, 3, 192, 192)
# Block8_3_Branch_1_Conv2d_0b_1x3_BatchNorm_beta.npy (192,)
# Block8_3_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_mean.npy (192,)
# Block8_3_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_variance.npy (192,)
# Block8_3_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_3_Branch_1_Conv2d_0c_3x1_kernel.npy (3, 1, 192, 192)
# Block8_3_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (192,)
# Block8_3_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_3_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_3_Branch_1_Conv2d_0c_3x1_BatchNorm_beta.npy (192,)
# Block8_3_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_mean.npy (192,)
# Block8_3_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_variance.npy (192,)
# Block8_3_Conv2d_1x1_kernel.npy (1, 1, 384, 1792)
# Block8_3_Conv2d_1x1_bias.npy (1792,)
# Block8_4_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_4_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Block8_4_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_4_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_4_Branch_1_Conv2d_0b_1x3_kernel.npy (1, 3, 192, 192)
# Block8_4_Branch_1_Conv2d_0b_1x3_BatchNorm_beta.npy (192,)
# Block8_4_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_mean.npy (192,)
# Block8_4_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_variance.npy (192,)
# Block8_4_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_4_Branch_1_Conv2d_0c_3x1_kernel.npy (3, 1, 192, 192)
# Block8_4_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (192,)
# Block8_4_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_4_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_4_Branch_1_Conv2d_0c_3x1_BatchNorm_beta.npy (192,)
# Block8_4_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_mean.npy (192,)
# Block8_4_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_variance.npy (192,)
# Block8_4_Conv2d_1x1_kernel.npy (1, 1, 384, 1792)
# Block8_4_Conv2d_1x1_bias.npy (1792,)
# Block8_5_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_5_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Block8_5_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_5_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_5_Branch_1_Conv2d_0b_1x3_kernel.npy (1, 3, 192, 192)
# Block8_5_Branch_1_Conv2d_0b_1x3_BatchNorm_beta.npy (192,)
# Block8_5_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_mean.npy (192,)
# Block8_5_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_variance.npy (192,)
# Block8_5_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_5_Branch_1_Conv2d_0c_3x1_kernel.npy (3, 1, 192, 192)
# Block8_5_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (192,)
# Block8_5_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_5_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_5_Branch_1_Conv2d_0c_3x1_BatchNorm_beta.npy (192,)
# Block8_5_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_mean.npy (192,)
# Block8_5_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_variance.npy (192,)
# Block8_5_Conv2d_1x1_kernel.npy (1, 1, 384, 1792)
# Block8_5_Conv2d_1x1_bias.npy (1792,)
# Block8_6_Branch_1_Conv2d_0a_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm_beta.npy (192,)
# Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_6_Branch_1_Conv2d_0b_1x3_kernel.npy (1, 3, 192, 192)
# Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm_beta.npy (192,)
# Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_mean.npy (192,)
# Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm_moving_variance.npy (192,)
# Block8_6_Branch_0_Conv2d_1x1_kernel.npy (1, 1, 1792, 192)
# Block8_6_Branch_1_Conv2d_0c_3x1_kernel.npy (3, 1, 192, 192)
# Block8_6_Branch_0_Conv2d_1x1_BatchNorm_beta.npy (192,)
# Block8_6_Branch_0_Conv2d_1x1_BatchNorm_moving_mean.npy (192,)
# Block8_6_Branch_0_Conv2d_1x1_BatchNorm_moving_variance.npy (192,)
# Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm_beta.npy (192,)
# Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_mean.npy (192,)
# Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm_moving_variance.npy (192,)
# Block8_6_Conv2d_1x1_kernel.npy (1, 1, 384, 1792)
# Block8_6_Conv2d_1x1_bias.npy (1792,)
# Bottleneck_kernel.npy (1792, 512)
# Bottleneck_BatchNorm_beta.npy (512,)
# Bottleneck_BatchNorm_moving_mean.npy (512,)
# Bottleneck_BatchNorm_moving_variance.npy (512,)
# Saving model...
